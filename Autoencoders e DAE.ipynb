# %% [markdown]
# <a href="https://colab.research.google.com/github/erbisti/Collab/blob/main/Autoencoders%20e%20DAE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ------------------ ARQUITETURA DO AUTOENCODER CONVOLUCIONAL ------------------
#
# """
# Autoencoder convolucional para imagens 28x28x1 (escala de cinza, como MNIST).
# Segue estrutura de compressão (encoder) e reconstrução (decoder), usando camadas Conv2D.
#
# ENTRADA: Imagem 28x28x1
#
# ENCODER:
# - Conv2D(16 filtros, 3x3, ReLU, padding='same')       → 28x28x16
# - MaxPooling2D(2x2, padding='same')                   → 14x14x16
# - Conv2D(8 filtros, 3x3, ReLU, padding='same')        → 14x14x8
# - MaxPooling2D(2x2, padding='same')                   → 7x7x8  ← espaço latente
#
# DECODER:
# - Conv2D(8 filtros, 3x3, ReLU, padding='same')        → 7x7x8
# - UpSampling2D(2x2)                                   → 14x14x8
# - Conv2D(16 filtros, 3x3, ReLU, padding='same')       → 14x14x16
# - UpSampling2D(2x2)                                   → 28x28x16
# - Conv2D(1 filtro, 3x3, Sigmoid, padding='same')      → 28x28x1 ← imagem reconstruída
#
# O modelo é simétrico, treinado com função de perda 'binary_crossentropy' e ativação final 'sigmoid'.
# """

# %%
# Importa o TensorFlow e módulos úteis
import tensorflow as tf
from tensorflow.keras import layers, models  # Camadas e modelos da Keras
import numpy as np
import matplotlib.pyplot as plt  # Para visualização dos resultados

# Carrega o conjunto de dados MNIST (imagens de dígitos manuscritos - base completa)
(x_train, _), (x_test, _) = tf.keras.datasets.mnist.load_data()
# Normaliza os pixels das imagens para o intervalo [0, 1]
x_train = x_train.astype("float32") / 255.
x_test = x_test.astype("float32") / 255.
# Adiciona o canal de cor (necessário para convoluções, apenas adiciona o "1" indicando profundidade)
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# INÍCIO DO MODELO AUTOENCODER

# Entrada da rede: imagem 28x28 com 1 canal (escala de cinza)
input_img = tf.keras.Input(shape=(28, 28, 1))

# CAMADAS DO ENCODER

# Primeira camada convolucional: extrai 16 mapas de características (features), usa ReLU, mantém tamanho com padding
x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
# Reduz pela metade o tamanho da imagem (28x28 → 14x14) com max pooling
x = layers.MaxPooling2D((2, 2), padding='same')(x)

# Segunda camada convolucional: extrai 8 mapas, mantém tamanho
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
# Reduz novamente (14x14 → 7x7)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# Nesse ponto, temos o espaço latente (codificado) de dimensão 7x7x8 = 392 features

# CAMADAS DO DECODER (reconstrói a imagem a partir do encoding)

# Primeira camada de decodificação: mantém tamanho e ativa com ReLU
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
# Aumenta o tamanho da imagem (7x7 → 14x14)
x = layers.UpSampling2D((2, 2))(x)

# Segunda camada: aumenta canais para 16 e mantém tamanho
x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(x)
# Aumenta tamanho novamente (14x14 → 28x28)
x = layers.UpSampling2D((2, 2))(x)

# Saída final: reconstrói a imagem original com 1 canal
# Usa sigmoide para gerar valores entre 0 e 1 (mesmo intervalo da entrada)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

# Define o modelo completo: da imagem de entrada à imagem reconstruída
autoencoder = models.Model(input_img, decoded)

# Compila o modelo usando o otimizador Adam e função de perda binária (adequada para [0,1])
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Mostra um resumo do modelo com número de parâmetros e camadas
autoencoder.summary()

# TREINAMENTO DO MODELO

# Treina o autoencoder:
# - entrada: imagem original
# - saída: imagem original (modelo aprende a reconstruí-la)
# - epochs: número de ciclos completos sobre o dataset
# - batch_size: quantas imagens por passo de atualização
# - shuffle: embaralha os dados a cada epoch
# - validation_data: usa x_test para ver desempenho fora do treino
autoencoder.fit(x_train, x_train,
                epochs=10,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test, x_test))

# APLICAÇÃO: Reconstrução das imagens de teste
decoded_imgs = autoencoder.predict(x_test)

# VISUALIZAÇÃO DOS RESULTADOS

# Exibe 10 imagens originais e suas reconstruções
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # Linha 1: imagens originais
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    ax.axis('off')

    # Linha 2: imagens reconstruídas
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    ax.axis('off')
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 28, 28, 16)     │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 14, 14, 8)      │         1,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 8)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 7, 7, 8)        │           584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 14, 14, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 14, 14, 16)     │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 28, 28, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 28, 28, 1)      │           145 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,217 (12.57 KB)
#  Trainable params: 3,217 (12.57 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - loss: 0.2751 - val_loss: 0.0884
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 81s 125ms/step - loss: 0.0868 - val_loss: 0.0808
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 80s 121ms/step - loss: 0.0808 - val_loss: 0.0778
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 83s 122ms/step - loss: 0.0781 - val_loss: 0.0761
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 82s 122ms/step - loss: 0.0768 - val_loss: 0.0753
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 82s 122ms/step - loss: 0.0758 - val_loss: 0.0744
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 83s 124ms/step - loss: 0.0749 - val_loss: 0.0738
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 80s 121ms/step - loss: 0.0746 - val_loss: 0.0734
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 83s 124ms/step - loss: 0.0739 - val_loss: 0.0730
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 80s 119ms/step - loss: 0.0737 - val_loss: 0.0727
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step

# %%
# REUTILIZA os dados MNIST já normalizados (assume x_train e x_test já carregados e processados anteriormente)
# Se não tiver rodado o código anterior, rode as 10 primeiras linhas da Parte 1 antes

# Parâmetro que define o nível de ruído a ser adicionado (pode ser ajustado)
noise_factor = 0.5

# Adiciona ruído Gaussiano às imagens de treino
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
# Adiciona ruído Gaussiano às imagens de teste
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

# Garante que os valores fiquem entre 0 e 1 (limite da ativação sigmoide)
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# REUTILIZA o mesmo modelo do autoencoder anterior (input_img → decoded)
# Se quiser criar outro modelo separado, pode duplicar a definição anterior com nome diferente

# Cria novo modelo chamado DAE (usa mesma arquitetura)
dae = models.Model(input_img, decoded)

# Compila o modelo com o mesmo otimizador e função de perda
dae.compile(optimizer='adam', loss='binary_crossentropy')

# TREINA o DAE:
# Entrada: imagens com ruído
# Saída: imagens sem ruído (originais)
dae.fit(x_train_noisy, x_train,
        epochs=10,
        batch_size=128,
        shuffle=True,
        validation_data=(x_test_noisy, x_test))

# Usa o modelo treinado para reconstruir as imagens ruidosas
decoded_imgs = dae.predict(x_test_noisy)

# VISUALIZAÇÃO: compara entrada ruidosa, reconstrução e imagem original
plt.figure(figsize=(20, 6))
for i in range(10):
    # Linha 1: entrada ruidosa
    ax = plt.subplot(3, 10, i + 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28), cmap='gray')
    ax.axis('off')

    # Linha 2: imagem reconstruída (saída do autoencoder)
    ax = plt.subplot(3, 10, i + 11)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    ax.axis('off')

    # Linha 3: imagem original sem ruído (para comparação)
    ax = plt.subplot(3, 10, i + 21)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    ax.axis('off')
plt.show()
# Out:
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 67s 137ms/step - loss: 0.1311 - val_loss: 0.1136
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 78s 128ms/step - loss: 0.1142 - val_loss: 0.1112
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 80s 125ms/step - loss: 0.1121 - val_loss: 0.1103
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 84s 129ms/step - loss: 0.1112 - val_loss: 0.1090
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 80s 125ms/step - loss: 0.1101 - val_loss: 0.1083
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 83s 128ms/step - loss: 0.1092 - val_loss: 0.1079
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 83s 131ms/step - loss: 0.1088 - val_loss: 0.1074
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 82s 130ms/step - loss: 0.1083 - val_loss: 0.1068
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 80s 126ms/step - loss: 0.1078 - val_loss: 0.1070
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 82s 127ms/step - loss: 0.1073 - val_loss: 0.1062
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
